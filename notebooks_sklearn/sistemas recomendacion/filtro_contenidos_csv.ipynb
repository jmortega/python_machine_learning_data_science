# %% [markdown]
# ### En este ejemplo, crearemos un sistema de recomendaciones que recomiende películas a los usuarios
# ### Utilizaremos el conjunto de datos movies.csv

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ### Para poder usar la columna movie_genre, tenemos que convertirla en un grupo de campos llamados dummy_variables.
#
# ### Esta función convierte una variable categórica (por ejemplo, el genéro de la película puede ser Animation, Comedy, Romance...), en múltiples columnas,uns para cada categoría
#
# ### Para cada película, éstas columnas dummy tendrán un valor de 0 excepto para aquellos géneros que tenga la película.

# %%
u_cols = ['movieId', 'title', 'genres']
movies = pd.read_csv('movies.csv',names=u_cols)
movies = movies[movies.movieId != 'movieId']
movies = pd.concat([movies, movies.genres.str.get_dummies(sep='|')], axis=1)

# %%
movie_categories = movies.columns[3:].tolist()

# %%
movies.head()
# Out:
#   movieId                               title  \
# 1       1                    Toy Story (1995)
# 2       2                      Jumanji (1995)
# 3       3             Grumpier Old Men (1995)
# 4       4            Waiting to Exhale (1995)
# 5       5  Father of the Bride Part II (1995)
#
#                                         genres  (no genres listed)  Action  \
# 1  Adventure|Animation|Children|Comedy|Fantasy                   0       0
# 2                   Adventure|Children|Fantasy                   0       0
# 3                               Comedy|Romance                   0       0
# 4                         Comedy|Drama|Romance                   0       0
# 5                                       Comedy                   0       0
#
#    Adventure  Animation  Children  Comedy  Crime   ...     Film-Noir  Horror  \
# 1          1          1         1       1      0   ...             0       0
# 2          1          0         1       0      0   ...             0       0
# 3          0          0         0       1      0   ...             0       0
# 4          0          0         0       1      0   ...             0       0
# 5          0          0         0       1      0   ...             0       0
#
#    IMAX  Musical  Mystery  Romance  Sci-Fi  Thriller  War  Western
# 1     0        0        0        0       0         0    0        0
# 2     0        0        0        0       0         0    0        0
# 3     0        0        0        1       0         0    0        0
# 4     0        0        0        1       0         0    0        0
# 5     0        0        0        0       0         0    0        0
#
# [5 rows x 23 columns]

# %%
movies.tail()
# Out:
#       movieId                                title                 genres  \
# 40106  165193                Tanya's Island (1980)  Drama|Fantasy|Romance
# 40107  165195                Pacific Banana (1981)                 Comedy
# 40108  165197  Werewolf in a Women's Prison (2006)     (no genres listed)
# 40109  165199      The Fearless Young Boxer (1979)                 Action
# 40110  165201                      Snatched (1973)   Crime|Drama|Thriller
#
#        (no genres listed)  Action  Adventure  Animation  Children  Comedy  \
# 40106                   0       0          0          0         0       0
# 40107                   0       0          0          0         0       1
# 40108                   1       0          0          0         0       0
# 40109                   0       1          0          0         0       0
# 40110                   0       0          0          0         0       0
#
#        Crime   ...     Film-Noir  Horror  IMAX  Musical  Mystery  Romance  \
# 40106      0   ...             0       0     0        0        0        1
# 40107      0   ...             0       0     0        0        0        0
# 40108      0   ...             0       0     0        0        0        0
# 40109      0   ...             0       0     0        0        0        0
# 40110      1   ...             0       0     0        0        0        0
#
#        Sci-Fi  Thriller  War  Western
# 40106       0         0    0        0
# 40107       0         0    0        0
# 40108       0         0    0        0
# 40109       0         0    0        0
# 40110       0         1    0        0
#
# [5 rows x 23 columns]

# %%
movies.title
# Out:
# 1                                         Toy Story (1995)
# 2                                           Jumanji (1995)
# 3                                  Grumpier Old Men (1995)
# 4                                 Waiting to Exhale (1995)
# 5                       Father of the Bride Part II (1995)
# 6                                              Heat (1995)
# 7                                           Sabrina (1995)
# 8                                      Tom and Huck (1995)
# 9                                      Sudden Death (1995)
# 10                                        GoldenEye (1995)
# 11                          American President, The (1995)
# 12                      Dracula: Dead and Loving It (1995)
# 13                                            Balto (1995)
# 14                                            Nixon (1995)
# 15                                 Cutthroat Island (1995)
# 16                                           Casino (1995)
# 17                            Sense and Sensibility (1995)
# 18                                       Four Rooms (1995)
# 19                   Ace Ventura: When Nature Calls (1995)
# 20                                      Money Train (1995)
# 21                                       Get Shorty (1995)
# 22                                          Copycat (1995)
# 23                                        Assassins (1995)
# 24                                           Powder (1995)
# 25                                Leaving Las Vegas (1995)
# 26                                          Othello (1995)
# 27                                     Now and Then (1995)
# 28                                       Persuasion (1995)
# 29       City of Lost Children, The (Cité des enfants p...
# 30       Shanghai Triad (Yao a yao yao dao waipo qiao) ...
#                                ...
# 40081                      What a Wonderful Family! (2016)
# 40082                                     Best Chef (2007)
# 40083                Le Grand Chef 2: Kimchi Battle (2010)
# 40084                                        Trolls (2016)
# 40085                                         45365 (2010)
# 40086                                       Western (2015)
# 40087                             Nightmare Sisters (1988)
# 40088    LEGO DC Comics Super Heroes: Batman: Be-League...
# 40089                 Russell Peters: Almost Famous (2016)
# 40090                                  Pedro Páramo (1967)
# 40091                              Breadcrumb Trail (2014)
# 40092                               Girl in the Box (2016)
# 40093                                      Raiders! (2016)
# 40094                              Finding Truelove (2012)
# 40095                                   Silver Lode (1954)
# 40096                                  dream/killer (2015)
# 40097                                 The Forgotten (2014)
# 40098                           Hidden in the Woods (2014)
# 40099                                            37 (2016)
# 40100                                      Obsessed (1992)
# 40101                               Island of Blood (1982)
# 40102              Slave Girls from Beyond Infinity (1987)
# 40103         Roller Blade Warriors: Taken by Force (1989)
# 40104                                Avenging Angel (1985)
# 40105                                     Mad Foxes (1981)
# 40106                                Tanya's Island (1980)
# 40107                                Pacific Banana (1981)
# 40108                  Werewolf in a Women's Prison (2006)
# 40109                      The Fearless Young Boxer (1979)
# 40110                                      Snatched (1973)
# Name: title, dtype: object

# %% [markdown]
# ### La película con una id de 25, Leaving Las Vegas, pertenece a los géneros Drama y romance

# %%
movies.loc[25]
# Out:
# movieId                                     25
# title                 Leaving Las Vegas (1995)
# genres                           Drama|Romance
# (no genres listed)                           0
# Action                                       0
# Adventure                                    0
# Animation                                    0
# Children                                     0
# Comedy                                       0
# Crime                                        0
# Documentary                                  0
# Drama                                        1
# Fantasy                                      0
# Film-Noir                                    0
# Horror                                       0
# IMAX                                         0
# Musical                                      0
# Mystery                                      0
# Romance                                      1
# Sci-Fi                                       0
# Thriller                                     0
# War                                          0
# Western                                      0
# Name: 25, dtype: object

# %%
movie_categories
# Out:
# ['(no genres listed)',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Children',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Film-Noir',
#  'Horror',
#  'IMAX',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Thriller',
#  'War',
#  'Western']

# %%
def get_user_preferences(user_movies):
    user_features = movies[movies.title.isin(user_movies)].ix[:,3:].T
    user_features = user_features.mean(axis=1).reset_index()
    print(user_features)
    return user_features.ix[:,1].tolist()

# %%
user_movies = [
    'Atari: Game Over (2014)',
    'Antarctica: A Year On Ice (2013)'
]

# %%
user_preferences_list = get_user_preferences(user_movies)
# Out:
#                  index    0
# 0   (no genres listed)  0.0
# 1               Action  0.0
# 2            Adventure  0.5
# 3            Animation  0.0
# 4             Children  0.0
# 5               Comedy  0.0
# 6                Crime  0.0
# 7          Documentary  1.0
# 8                Drama  0.0
# 9              Fantasy  0.0
# 10           Film-Noir  0.0
# 11              Horror  0.0
# 12                IMAX  0.0
# 13             Musical  0.0
# 14             Mystery  0.0
# 15             Romance  0.0
# 16              Sci-Fi  0.0
# 17            Thriller  0.0
# 18                 War  0.0
# 19             Western  0.0

# %%
def get_predicted_movie_score(movie_name, user_preferences):
    movie_slice = movies[movies.title==movie_name].iloc[0]
    movie_features = movie_slice[movie_categories]
    return np.dot(movie_features, user_preferences)

# %%
#Action +Sci-Fi + Thriller #no te la recomienda
get_predicted_movie_score('Armageddon (1998)', user_preferences_list)
# Out:
# 0.0

# %%
#Documentary #recomendable
get_predicted_movie_score('Lambert & Stamp (2014)', user_preferences_list)
# Out:
# 1.0

# %%
#Adventure #recomendable
get_predicted_movie_score('The Great Alone (2015)', user_preferences_list)
# Out:
# 1.5

# %%
def get_movie_recommendations(user_preferences, number_recommendations):
    movies['score'] =movies.title.apply(get_predicted_movie_score, args=([user_preferences]))
    movies.sort_values(by=['score'], ascending=False, inplace=True)
    return movies[['title','genres','score']].head(number_recommendations)

get_movie_recommendations(user_preferences_list, 10)
# Out:
#                                                    title  \
# 16459                                  Sweetgrass (2009)
# 34757                          Steak (R)évolution (2014)
# 19524                               Bigfoot Lives (2007)
# 23908                             Ride the Divide (2010)
# 38703                             The Great Alone (2015)
# 14070  Wings of Hope (Julianes Sturz in den Dschungel...
# 440                         Endless Summer 2, The (1994)
# 27916                          Project Wild Thing (2013)
# 7943                             Freedom Downtime (2001)
# 9889                        Incident at Loch Ness (2004)
#
#                                      genres  score
# 16459         Adventure|Documentary|Western    1.5
# 34757        Adventure|Children|Documentary    1.5
# 19524           Adventure|Documentary|Drama    1.5
# 23908                 Adventure|Documentary    1.5
# 38703           Adventure|Documentary|Drama    1.5
# 14070                 Adventure|Documentary    1.5
# 440                   Adventure|Documentary    1.5
# 27916  Adventure|Children|Documentary|Drama    1.5
# 7943            Adventure|Crime|Documentary    1.5
# 9889           Adventure|Comedy|Documentary    1.5

# %%
#obtener recomendaciones a partir de los gustos del usuario

from collections import OrderedDict

user_preferences = OrderedDict(zip(movie_categories, []))

user_preferences['(no genres listed)'] = 0 
user_preferences['Action'] = 1  
user_preferences['Adventure'] = 1  
user_preferences['Animation'] = 5  
user_preferences["Children's"] = 0  
user_preferences["Comedy"] = 1  
user_preferences['Crime'] = 1  
user_preferences['Documentary'] = 1  
user_preferences['Drama'] = 1  
user_preferences['Fantasy'] = 1  
user_preferences['Film-Noir'] = 1  
user_preferences['Horror'] = 0
user_preferences['IMAX'] = 1 
user_preferences['Musical'] = 1  
user_preferences['Mystery'] = 1  
user_preferences['Romance'] = 1  
user_preferences['Sci-Fi'] = 5  
user_preferences['War'] = 1  
user_preferences['Thriller'] = 1  
user_preferences['Western'] =1  

user_preferences_list = list(user_preferences.values())

# %%
get_movie_recommendations(user_preferences_list, 10)
# Out:
#                                                    title  \
# 9003   Patlabor: The Movie (Kidô keisatsu patorebâ: T...
# 11812  Aqua Teen Hunger Force Colon Movie Film for Th...
# 11236                                   Mind Game (2004)
# 39026               Kingsglaive: Final Fantasy XV (2016)
# 9829                                       Robots (2005)
# 31966  Mobile Suit Gundam III: Encounters in Space (1...
# 31965   Mobile Suit Gundam II: Soldiers of Sorrow (1981)
# 16901                             Mars Needs Moms (2011)
# 13117                     Futurama: Bender's Game (2008)
# 34037                      Princes and Princesses (2000)
#
#                                                   genres  score
# 9003   Action|Animation|Crime|Drama|Film-Noir|Mystery...     16
# 11812  Action|Adventure|Animation|Comedy|Fantasy|Myst...     15
# 11236  Adventure|Animation|Comedy|Fantasy|Romance|Sci-Fi     14
# 39026    Action|Adventure|Animation|Drama|Fantasy|Sci-Fi     14
# 9829   Adventure|Animation|Children|Comedy|Fantasy|Sc...     14
# 31966        Action|Adventure|Animation|Drama|Sci-Fi|War     14
# 31965        Action|Adventure|Animation|Drama|Sci-Fi|War     14
# 16901  Action|Adventure|Animation|Children|Comedy|Sci...     14
# 13117   Action|Adventure|Animation|Comedy|Fantasy|Sci-Fi     14
# 34037  Animation|Children|Comedy|Drama|Fantasy|Romanc...     14
