# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Leer csv con pandas

# %%
import pandas as pd
titanic_train = pd.read_csv("titanic.csv")

# %%
titanic_train
# Out:
#       row.names pclass  survived  \
# 0             1    1st         1
# 1             2    1st         0
# 2             3    1st         0
# 3             4    1st         0
# 4             5    1st         1
# 5             6    1st         1
# 6             7    1st         1
# 7             8    1st         0
# 8             9    1st         1
# 9            10    1st         0
# 10           11    1st         0
# 11           12    1st         1
# 12           13    1st         1
# 13           14    1st         1
# 14           15    1st         0
# 15           16    1st         1
# 16           17    1st         0
# 17           18    1st         0
# 18           19    1st         1
# 19           20    1st         1
# 20           21    1st         1
# 21           22    1st         0
# 22           23    1st         1
# 23           24    1st         1
# 24           25    1st         1
# 25           26    1st         0
# 26           27    1st         1
# ...

# %% [markdown]
# ## Localizaciones de usuarios

# %%
users = pd.read_csv("users.csv")

# %%
users
# Out:
#             id_str      screen_name                  name  \
# 0        136537109       BlueZ_2909                 yay⚓️
# 1        113823751          tommo_k              Tom Kane
# 2         28650462      kalpak_shah           Kalpak Shah
# 3        320991816    BethanyBennet           im a senior
# 4         20952459       Doobiesbar           Doobies Bar
# 5        123134195       chenyaobai            chenyaobai
# 6        562084427       KaraVernon             K-breezy!
# 7        146037767       nikicucina                 Niki
# 8       2893900385    AveryTee01994             Avery Tee
# 9        282271180  IniallATE_Xcuse        Niall Harrison
# 10      2165859476     EmilioRRFans    EmilioReadyRevFans
# 11       301161970        wmaxwell7          bill maxwell
# 12        45955618    Ben_Snodgrass         Ben Snodgrass
# 13      1434509905     pooler_marie     Lisa-Marie Pooler
# 14      3060245787        SunSeaPub  Sun and Sea Publishi
# ...

# %%
print("Numero de usuarios: %d" % len(users))
print("Localizaciones unicas: %d" % len(users.location.value_counts()))
# Out:
# Numero de usuarios: 199555
# Localizaciones unicas: 61991

# %% [markdown]
# ## Obtener localizaciones con contador asociado

# %%
users.location.value_counts()
# Out:
# New York                          1119
# Los Angeles                        847
# Los Angeles, CA                    784
# Chicago                            726
# Manchester                         640
# New York, NY                       629
# Chicago, IL                        627
# USA                                496
# Canada                             459
# Atlanta, GA                        445
# California                         412
# New York City                      402
# Indonesia                          396
# Washington, DC                     387
# Boston, MA                         364
# Texas                              357
# San Francisco                      342
# Houston, TX                        342
# Birmingham                         341
# San Francisco, CA                  336
# México                             329
# Colombia                           326
# Seattle, WA                        320
# Austin, TX                         313
# ...
